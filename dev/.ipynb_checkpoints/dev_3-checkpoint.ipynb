# %% [markdown]
# # Dev 3: Pipeline calling API Spotify
#
# In this notebook there are several things implemented:
#
# - Spotipy credentials to connect to API Spotify
# - API call to retrieve an artist
# - Check the string similarity with the query

# %%
import pandas as pd
import sys
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
import requests
import datetime
import base64
import re
from collections import Counter
import psycopg2

# %% [markdown]
# ### Dataframe

# %%
types_cols = {
    "mbid":object,
    "artist_mb":object,
    "artist_lastfm":object,
    "country_mb":object,
    "country_lastfm":object,
    "tags_mb":object,
    "tags_lastfm":object,
    "listeners_lastfm": np.float64,
    "scrobbles_lastfm":np.float64,
    "ambiguous_artist":bool
    }

# %%
df = pd.read_csv("../data/artists.csv", dtype=types_cols)
# Out:
# c:\users\david\.virtualenvs\spotify-esbtn7ng\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (2,4,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.sort_values("listeners_lastfm", ascending=False, inplace=True)

# %%
df.head()
# Out:
#                                    mbid              artist_mb  \
# 0  cc197bad-dc9c-440d-a5b5-d52ba2e14234               Coldplay
# 1  a74b1b7f-71a5-4011-9441-d0b5e4122711              Radiohead
# 2  8bfac288-ccc5-448d-9573-c33ea2aa5c30  Red Hot Chili Peppers
# 3  73e5e69d-3554-40d8-8516-00cb38737a1c                Rihanna
# 4  b95ce3ff-3d05-4e87-9e01-c97b66af13d4                 Eminem
#
#            artist_lastfm      country_mb           country_lastfm  \
# 0               Coldplay  United Kingdom           United Kingdom
# 1              Radiohead  United Kingdom           United Kingdom
# 2  Red Hot Chili Peppers   United States            United States
# 3                Rihanna   United States  Barbados; United States
# 4                 Eminem   United States            United States
#
#                                              tags_mb  \
# 0  rock; pop; alternative rock; british; uk; brit...
# 1  rock; electronic; alternative rock; british; g...
# 2  rock; alternative rock; 80s; 90s; rap; metal; ...
# 3  pop; dance; hip hop; reggae; contemporary r b;...
# 4  turkish; rap; american; hip-hop; hip hop; hiph...
#
#                                          tags_lastfm  listeners_lastfm  \
# 0  rock; alternative; britpop; alternative rock; ...         5381567.0
# 1  alternative; alternative rock; rock; indie; el...         4732528.0
# 2  rock; alternative rock; alternative; Funk Rock...         4620835.0
# 3  pop; rnb; female vocalists; dance; Hip-Hop; Ri...         4558193.0
# 4  rap; Hip-Hop; Eminem; hip hop; pop; american; ...         4517997.0
#
#    scrobbles_lastfm  ambiguous_artist
# 0       360111850.0             False
# 1       499548797.0             False
# 2       293784041.0             False
# 3       199248986.0             False
# 4       199507511.0             False

# %%
df_sample = df.loc[1:1000]

# %%
df.loc[738]
# Out:
# mbid                             4e045c96-538b-46ed-8ea8-7cae20b56574
# artist_mb                                                   The Vines
# artist_lastfm                                               The Vines
# country_mb                                                  Australia
# country_lastfm                                                    NaN
# tags_mb             rock; alternative rock; australian; indie rock...
# tags_lastfm         rock; indie; indie rock; alternative; alternat...
# listeners_lastfm                                               949278
# scrobbles_lastfm                                          1.48536e+07
# ambiguous_artist                                                False
# Name: 738, dtype: object

# %%
df[df["artist_mb"].str.lower() == "you me at six"]
# Out:
#                                       mbid      artist_mb  artist_lastfm  \
# 1281  fb4fc5a6-cbe1-45ff-954c-ef45faceb54d  You Me at Six  You Me at Six
#
#           country_mb country_lastfm tags_mb  \
# 1281  United Kingdom            NaN     NaN
#
#                                         tags_lastfm  listeners_lastfm  \
# 1281  pop punk; rock; seen live; pop rock; powerpop          648189.0
#
#       scrobbles_lastfm  ambiguous_artist
# 1281        28275653.0             False

# %%
df[df["artist_mb"].str.lower() == "rosalía"]
# Out:
#                                          mbid artist_mb artist_lastfm  \
# 11882    ac0ee862-a6ca-4d39-a7a4-d8460534ba30   Rosalía       Rosalía
# 1461688  25f3abd9-63b5-471a-bd25-feb9672dfa11   ROSALÍA           NaN
#
#         country_mb         country_lastfm                 tags_mb  \
# 11882        Spain  Spain; United Kingdom                     NaN
# 1461688      Spain                    NaN  flamenco; flamenco pop
#
#                                                tags_lastfm  listeners_lastfm  \
# 11882    Flamenco; pop; spanish; spain; Flamenco Nuevo;...           91555.0
# 1461688                                                NaN               NaN
#
#          scrobbles_lastfm  ambiguous_artist
# 11882           3762940.0             False
# 1461688               NaN             False

# %%
df_sample = df[df["listeners_lastfm"] > 200000]

# %%
def get_max_str_column(df_in, col):
    """
    #get_max_str_column(df_sample, "country_mb")
    """
    set_country = set(df_in[col])
    max_l = 0
    element = ""
    for cc in list(set_country):
        if type(cc) == str:
            if len(cc) > max_l:
                max_l = len(cc)
                element= cc
    return max_l, element

# %%
tags = df_sample.tags_lastfm.str.split(';').tolist()

# %%
all_tags = []
for tt in tags:
    if tt is not np.nan:
        for xx in tt:
            all_tags.append(xx.strip().lower())

# %%
set_tags = set(all_tags)

# %%
len(set_tags)
# Out:
# 22410

# %%
dict_counter = Counter(all_tags)

# %%
dict_counter_sort = {k: v for k, v in sorted(dict_counter.items(), key = lambda item: item[1], reverse= True)}

# %%
dict_counter_sort
# Out:
# {'seen live': 3923,
#  'rock': 3194,
#  'alternative': 2858,
#  'pop': 2856,
#  'indie': 2430,
#  'american': 2232,
#  'electronic': 2151,
#  'male vocalists': 1856,
#  'usa': 1790,
#  '00s': 1665,
#  'alternative rock': 1556,
#  'singer-songwriter': 1513,
#  'indie rock': 1374,
#  'dance': 1341,
#  'electronica': 1338,
#  'female vocalists': 1309,
#  '90s': 1274,
#  'chillout': 1217,
#  'experimental': 1178,
#  'soul': 1097,
#  'indie pop': 1063,
#  'hip-hop': 1037,
#  'folk': 1035,
#  'british': 1003,
#  '80s': 996,
#  'all': 968,
#  'classic rock': 955,
#  'jazz': 936,
#  'pop rock': 892,
#  'metal': 892,
#  'punk': 885,
#  'favorites': 882,
#  'acoustic': 868,
#  'electro': 841,
#  'hip hop': 808,
#  'female vocalist': 801,
#  'uk': 798,
#  'ambient': 785,
#  'hard rock': 768,
#  'rap': 768,
#  'funk': 757,
#  'chill': 732,
#  'rnb': 712,
#  'english': 700,
#  'female': 698,
#  'instrumental': 664,
#  'love': 655,
#  'emo': 630,
#  'house': 607,
#  '70s': 606,
#  'psychedelic': 599,
#  'blues': 597,
#  'new wave': 580,
#  'mellow': 575,
#  'punk rock': 559,
#  'downtempo': 557,
#  'oldies': 539,
#  'progressive rock': 528,
#  'soundtrack': 515,
#  'trip-hop': 501,
#  'hardcore': 499,
#  'synthpop': 495,
#  'electropop': 494,
#  'easy listening': 490,
#  'techno': 487,
#  'england': 484,
#  'heavy metal': 481,
#  'beautiful': 480,
#  'sexy': 475,
#  'awesome': 473,
#  '60s': 460,
#  'r&b': 453,
#  'folk rock': 434,
#  'male vocalist': 428,
#  'soft rock': 415,
#  'guitar': 413,
#  'disco': 389,
#  'britpop': 387,
#  'california': 387,
#  'trance': 373,
#  'hiphop': 372,
#  'rhythm and blues': 371,
#  'post-punk': 371,
#  'country': 368,
#  'lounge': 367,
#  'new york': 362,
#  'piano': 358,
#  '10s': 353,
#  'pop-rock': 350,
#  'reggae': 339,
#  'lo-fi': 336,
#  'urban': 334,
#  'favorite': 330,
#  'indie folk': 325,
#  'dream pop': 312,
#  'female vocals': 308,
#  'progressive': 301,
#  'classic': 297,
#  'death metal': 292,
#  'german': 288,
#  'funky': 287,
#  'synth pop': 283,
#  'indietronica': 269,
#  'post-rock': 268,
#  'pop punk': 256,
#  'psychedelic rock': 253,
#  'idm': 250,
#  'dubstep': 250,
#  'atmospheric': 249,
#  'fun': 248,
#  'amazing': 247,
#  'vocal': 247,
#  'underground hip-hop': 247,
#  'club': 242,
#  'world': 236,
#  'london': 235,
#  'grunge': 232,
#  'alternative metal': 231,
#  'metalcore': 231,
#  'blues rock': 230,
#  'americana': 227,
#  'alt-country': 226,
#  'male': 224,
#  'acid jazz': 224,
#  'classical': 224,
#  'canadian': 221,
#  'swedish': 219,
#  'industrial': 215,
#  'female voices': 215,
#  'screamo': 214,
#  'cool': 212,
#  'shoegaze': 212,
#  'gay': 211,
#  'melancholy': 210,
#  'germany': 210,
#  'dance-pop': 208,
#  'romantic': 205,
#  'minimal': 202,
#  'dub': 199,
#  'latin': 199,
#  'power pop': 196,
#  'drum and bass': 196,
#  'r and b': 195,
#  'french': 194,
#  'trip hop': 194,
#  "80's": 193,
#  'post-hardcore': 193,
#  'art rock': 192,
#  'female vocal': 192,
#  'avant-garde': 188,
#  'smooth': 187,
#  'relaxing': 187,
#  'gangsta rap': 186,
#  'thrash metal': 186,
#  'los angeles': 186,
#  'progressive metal': 185,
#  'black metal': 183,
#  'ska': 181,
#  'neo-soul': 177,
#  'post-grunge': 175,
#  'melancholic': 174,
#  'rock and roll': 174,
#  'old school': 174,
#  'groove': 174,
#  'fusion': 173,
#  'spotify': 173,
#  'united states': 172,
#  'composer': 172,
#  'relax': 170,
#  'alternative pop': 170,
#  'legend': 169,
#  'nu metal': 167,
#  'noise': 167,
#  'electro house': 166,
#  'deutsch': 165,
#  'canada': 164,
#  'shit': 163,
#  'rock n roll': 162,
#  'genius': 160,
#  'breakbeat': 160,
#  'check out': 160,
#  "r'n'b": 158,
#  'garage rock': 158,
#  'ethereal': 158,
#  '2010s': 158,
#  'experimental rock': 157,
#  'officially shit': 157,
#  'folk-rock': 156,
#  'eurodance': 155,
#  'party': 154,
#  'sweden': 154,
#  'alternative hip-hop': 152,
#  'world music': 152,
#  'dreamy': 152,
#  'progressive house': 151,
#  'electroclash': 151,
#  'favourites': 149,
#  'underground rap': 146,
#  'favorite artists': 145,
#  'japanese': 145,
#  'smooth jazz': 143,
#  'hot': 140,
#  'political': 140,
#  'happy': 140,
#  'adult contemporary': 140,
#  'nu jazz': 140,
#  '50s': 139,
#  'synth': 139,
#  'gothic': 139,
#  'dj': 138,
#  'dance pop': 137,
#  'composers': 136,
#  'deep house': 133,
#  'neo soul': 133,
#  'contemporary classical': 133,
#  'australian': 131,
#  'female artists': 131,
#  'underground': 131,
#  'guilty pleasure': 130,
#  'retro': 130,
#  'scandinavian': 130,
#  'united kingdom': 130,
#  'alternative rap': 129,
#  'glam rock': 127,
#  'east coast rap': 127,
#  'france': 125,
#  'singer songwriter': 123,
#  'beats': 123,
#  'diva': 121,
#  'emocore': 120,
#  'indie electronic': 119,
#  'dirty south': 119,
#  "90's": 117,
#  'swing': 116,
#  'melodic metal': 115,
#  'new age': 114,
#  'pop-punk': 113,
#  'spanish': 113,
#  'hardcore punk': 113,
#  'underground hip hop': 113,
#  'acoustic rock': 112,
#  'country rock': 112,
#  'dark': 112,
#  'cute': 112,
#  'groovy': 112,
#  'texas': 111,
#  'ballad': 111,
#  'power metal': 111,
#  'melodic death metal': 111,
#  'glitch': 111,
#  'christian': 109,
#  'post rock': 109,
#  'art pop': 107,
#  'bass': 107,
#  'chillwave': 107,
#  'neo-psychedelia': 105,
#  'one hit wonder': 105,
#  'southern rock': 104,
#  'orchestral': 104,
#  'post hardcore': 104,
#  'chill out': 104,
#  'east coast': 103,
#  'synth-pop': 103,
#  'progressive trance': 103,
#  'garage': 101,
#  'post punk': 101,
#  'soft': 101,
#  'music': 101,
#  'hardcore rap': 100,
#  'nu-metal': 100,
#  'nyc': 100,
#  'gothic metal': 100,
#  'songwriter': 100,
#  'guilty pleasures': 99,
#  '2000s': 99,
#  'jazzy': 99,
#  '80s pop': 99,
#  'powerpop': 98,
#  'soundtracks': 97,
#  'electro pop': 96,
#  'dancehall': 95,
#  'australia': 95,
#  'europop': 95,
#  'jecks': 95,
#  'sweet': 94,
#  'chamber pop': 94,
#  'crap': 93,
#  'doom metal': 93,
#  'underrated': 93,
#  'epic': 92,
#  'vocal jazz': 92,
#  'space rock': 90,
#  'want to see live': 89,
#  'catchy': 89,
#  'baroque pop': 89,
#  'southern rap': 89,
#  'gothic rock': 88,
#  'aor': 88,
#  'instrumental hip-hop': 88,
#  'glam': 87,
#  'brutal death metal': 86,
#  'motown': 86,
#  'slow jams': 86,
#  'chicago': 85,
#  'gangsta': 85,
#  'favourite': 85,
#  'ost': 85,
#  'minimal techno': 85,
#  'contemporary rnb': 84,
#  'psychedelic pop': 84,
#  'guitar virtuoso': 84,
#  'love songs': 84,
#  'italian': 84,
#  'east coast hip-hop': 83,
#  'new rave': 83,
#  'melodic hardcore': 83,
#  'twee': 83,
#  'folk pop': 83,
#  'drum n bass': 83,
#  'pop rap': 82,
#  'brooklyn': 82,
#  'singer-songwriters': 82,
#  'nu-jazz': 82,
#  'myjukebox': 82,
#  'lovely': 81,
#  'freak folk': 81,
#  "70's": 81,
#  'tech house': 81,
#  'modern classical': 81,
#  'vocal trance': 81,
#  '<3': 80,
#  'european': 80,
#  'crossover': 79,
#  'darkwave': 79,
#  'great lyricists': 79,
#  'dnb': 79,
#  'brit pop': 78,
#  'teen pop': 78,
#  'georgia': 78,
#  'post grunge': 77,
#  'stoner rock': 77,
#  'adult alternative': 77,
#  'melodic rock': 77,
#  'noise rock': 77,
#  'breaks': 77,
#  'quirky': 76,
#  'sad': 76,
#  'bossa nova': 76,
#  'jazz vocal': 75,
#  'trap': 75,
#  'modern rock': 74,
#  'alternative dance': 73,
#  'rockabilly': 73,
#  'electro-pop': 73,
#  'comedy': 73,
#  'us': 73,
#  'love at first listen': 72,
#  'christian rock': 72,
#  'dark ambient': 72,
#  'blues-rock': 71,
#  'industrial metal': 71,
#  'live': 71,
#  'r n b': 70,
#  'modern country': 70,
#  'quiet storm': 70,
#  'jazz fusion': 70,
#  'abstract hip-hop': 70,
#  'piano rock': 69,
#  'edm': 69,
#  'real hip-hop': 69,
#  'queer': 69,
#  'neoclassical': 69,
#  'brazilian': 69,
#  'noise pop': 68,
#  'grime': 68,
#  'new york city': 68,
#  'polish': 68,
#  'psytrance': 68,
#  'detroit': 67,
#  'rapcore': 67,
#  'summer': 67,
#  'score': 67,
#  '3': 66,
#  'christmas': 66,
#  'alternative country': 66,
#  'japan': 66,
#  'latino': 65,
#  'roots': 65,
#  '1990s': 65,
#  'irish': 64,
#  'scottish': 64,
#  'contemporary country': 64,
#  'grindcore': 64,
#  'indietronic': 64,
#  'danish': 64,
#  'college rock': 63,
#  'crunk': 63,
#  'alt rock': 63,
#  'new romantic': 62,
#  'jamaica': 62,
#  'minimalism': 62,
#  'misc': 62,
#  'good': 61,
#  'female singer-songwriter': 61,
#  'psychedelic folk': 61,
#  "drum'n'bass": 61,
#  '1980s': 61,
#  'j-pop': 61,
#  'producer': 60,
#  'alternative hip hop': 60,
#  'avantgarde': 60,
#  'deathcore': 60,
#  'roots reggae': 60,
#  'hair metal': 59,
#  'not emo': 59,
#  'west coast': 59,
#  'latin pop': 59,
#  'russian': 59,
#  'duyster': 59,
#  'seattle': 58,
#  'gospel': 58,
#  'duo': 58,
#  'new jersey': 58,
#  'brazil': 58,
#  'turntablism': 58,
#  'post-punk revival': 57,
#  'glam metal': 57,
#  'atlanta': 57,
#  'black': 57,
#  'elektro': 57,
#  'brit rock': 56,
#  'michigan': 56,
#  'speed metal': 56,
#  'symphonic metal': 56,
#  'norwegian': 56,
#  'slowcore': 56,
#  'acid': 56,
#  'film score': 56,
#  'nu disco': 56,
#  'j-rock': 56,
#  'swag': 55,
#  'thrash': 55,
#  'jazz hop': 55,
#  'drone': 55,
#  'dutch': 55,
#  'uk garage': 55,
#  'psychedelic trance': 55,
#  'southern hip-hop': 54,
#  'industrial rock': 54,
#  'alt country': 54,
#  'ska punk': 54,
#  'downbeat': 54,
#  'drum & bass': 54,
#  'melodic': 54,
#  "bands i've seen live": 54,
#  'recommended': 53,
#  'prog': 53,
#  'goth': 53,
#  'funny': 53,
#  'alternative folk': 53,
#  'bebop': 53,
#  'jungle': 53,
#  'saxophone': 53,
#  'brasil': 53,
#  'good music': 52,
#  'electronic rock': 52,
#  'dance punk': 52,
#  'espanol': 52,
#  'country pop': 52,
#  "60's": 52,
#  'ninja tune': 52,
#  'movie score composers': 52,
#  'wonky': 52,
#  'live gesehen': 52,
#  'funk rock': 51,
#  'french house': 51,
#  'french touch': 51,
#  'scotland': 51,
#  'illinois': 51,
#  'stoner': 51,
#  'contemporary jazz': 51,
#  'jamaican': 51,
#  'east coast hip hop': 51,
#  'ragga': 51,
#  'bluegrass': 51,
#  'new': 51,
#  'done': 51,
#  'black music': 50,
#  '40s': 50,
#  'album rock': 50,
#  'florida': 50,
#  'reggaeton': 50,
#  'abstract': 50,
#  'contemporary folk': 50,
#  'rave': 50,
#  'male country': 50,
#  'eurobeat': 50,
#  'sex': 49,
#  'surf rock': 49,
#  'west coast rap': 49,
#  'uitluisteren artist': 49,
#  'new weird america': 49,
#  'folktronica': 49,
#  'pennsylvania': 49,
#  'swedish metal': 49,
#  'alternative rnb': 48,
#  'skitz0rz': 48,
#  'favourite artists': 48,
#  'aussie': 48,
#  'midwest': 48,
#  'norway': 48,
#  'symphonic': 48,
#  'eurovision': 48,
#  'girls': 48,
#  'finnish': 48,
#  'chillosophy': 48,
#  'holloween skitz0rz': 47,
#  'doom': 47,
#  'classical music': 47,
#  'singer/songwriter': 47,
#  'instrumental hip hop': 47,
#  'francais': 47,
#  'goa': 47,
#  'anime': 47,
#  'punk-rock': 46,
#  'surf': 46,
#  'groove metal': 46,
#  'ambient pop': 46,
#  'emotional': 46,
#  'mpb': 46,
#  'italy': 46,
#  'neurofunk': 46,
#  'britrock': 45,
#  'british rock': 45,
#  'blue-eyed soul': 45,
#  'vocal house': 45,
#  'old school rap': 45,
#  'remix': 45,
#  'klassik': 45,
#  'new country': 45,
#  'berlin': 45,
#  'shady': 44,
#  '80s rock': 44,
#  'welsh': 44,
#  'southern': 44,
#  'instrumental rock': 44,
#  'film music': 44,
#  'melodic metalcore': 43,
#  'jazz rock': 43,
#  'hippie': 43,
#  'hardcore hip-hop': 43,
#  'nostalgia': 43,
#  'dope': 43,
#  'like': 43,
#  'symphonic rock': 42,
#  'my dance room': 42,
#  'español': 42,
#  'portuguese': 42,
#  '90s rock': 42,
#  'female singers': 42,
#  'dance-punk': 42,
#  'jam': 42,
#  'ethnic': 42,
#  "grey's anatomy": 42,
#  'cafe del mar': 42,
#  'to listen': 42,
#  'new jack swing': 41,
#  'sunflower': 41,
#  'twee pop': 41,
#  'math rock': 41,
#  'birp': 41,
#  'pretty': 41,
#  'dark electro': 41,
#  'overrated': 40,
#  'proto-punk': 40,
#  'west coast hip-hop': 40,
#  'fav888': 40,
#  'san francisco': 40,
#  'nu soul': 40,
#  'not screamo': 40,
#  'opera': 40,
#  'oldschool': 40,
#  'drugs': 40,
#  'contemporary': 40,
#  'glitch-hop': 40,
#  'rap rock': 39,
#  'classic country': 39,
#  'ebm': 39,
#  'breakcore': 39,
#  'calm': 39,
#  'melodic punk': 39,
#  'disney': 39,
#  'boom bap': 39,
#  'girl groups': 39,
#  'wales': 39,
#  'nu rave': 39,
#  'acid house': 39,
#  'jazz piano': 39,
#  'celtic': 39,
#  'my favorites': 39,
#  'uk hip-hop': 39,
#  'rap us': 39,
#  'asian': 39,
#  'experimental hip-hop': 39,
#  'progressive death metal': 39,
#  'technical death metal': 39,
#  'italo disco': 39,
#  'arena rock': 38,
#  'traditional country': 38,
#  "rock 'n' roll": 38,
#  'big band': 38,
#  'big beat': 38,
#  'psychedelia': 38,
#  'sensual': 38,
#  'd': 38,
#  'my country': 38,
#  'seenlive': 38,
#  'techstep': 38,
#  'visual kei': 38,
#  'chanson': 38,
#  'jpop': 38,
#  'manchester': 37,
#  'krautrock': 37,
#  'minnesota': 37,
#  'the worst thing ever to happen to music': 37,
#  'nu-disco': 37,
#  'rasta': 37,
#  'bands ive seen live': 37,
#  'energetic': 37,
#  'disco house': 37,
#  'dead': 36,
#  'washington': 36,
#  'poetry': 36,
#  'female fronted metal': 36,
#  'skate punk': 36,
#  'french electro': 36,
#  'movie soundtrack': 36,
#  'boybands': 36,
#  'hardcore hip hop': 36,
#  'f': 36,
#  'future garage': 36,
#  'luisterpaal': 36,
#  'cinematic': 36,
#  'punkrock': 35,
#  'eclectic': 35,
#  'female fronted': 35,
#  'roots rock': 35,
#  '4ad': 35,
#  'sadcore': 35,
#  'classic jazz': 35,
#  'ambient techno': 35,
#  'hard bop': 35,
#  'boy band': 35,
#  "d'n'b": 35,
#  'weird': 35,
#  'romance': 35,
#  'toronto': 34,
#  'prog rock': 34,
#  "rock'n'roll": 34,
#  'ohio': 34,
#  'trash': 34,
#  'rock en espanol': 34,
#  'ska-punk': 34,
#  'group': 34,
#  'mathcore': 34,
#  'philadelphia': 34,
#  '2014': 34,
#  'cover': 34,
#  'male vocal': 34,
#  'netherlands': 34,
#  'c': 34,
#  'solo': 34,
#  'neo-classical': 34,
#  'samba': 34,
#  'dirty electro': 34,
#  'polskie': 34,
#  'eletronic': 33,
#  'triphop': 33,
#  'southern hip hop': 33,
#  'band': 33,
#  'smooth soul': 33,
#  'romanian': 33,
#  'slow': 33,
#  'minimalist': 33,
#  'spain': 33,
#  'spanish pop': 33,
#  'brostep': 33,
#  'jazz-funk': 33,
#  'funky house': 33,
#  'post-dubstep': 33,
#  'old school death metal': 33,
#  'chanson francaise': 33,
#  'checkout': 33,
#  'dance rock': 32,
#  'jangle pop': 32,
#  'old school hip hop': 32,
#  'conscious hip hop': 32,
#  'guys i would fuck': 32,
#  'free jazz': 32,
#  'jazz rap': 32,
#  'nordic': 32,
#  'contemporary r&b': 32,
#  'tech-house': 32,
#  'uplifting trance': 32,
#  'northern soul': 32,
#  'trippy': 32,
#  'groups': 32,
#  'multiple artists': 32,
#  'video game music': 32,
#  'garage rock revival': 31,
#  'guitar hero': 31,
#  'boston': 31,
#  'massachusetts': 31,
#  'golden age': 31,
#  'old school hip-hop': 31,
#  'baroque': 31,
#  'indie dance': 31,
#  'indiepop': 31,
#  'post-bop': 31,
#  'movie score': 31,
#  'listen': 31,
#  'french pop': 31,
#  'love it': 31,
#  'francophone': 31,
#  "00's": 31,
#  'relevant magazine': 31,
#  'lush': 31,
#  'brazilian music': 31,
#  'deep': 31,
#  'full on': 31,
#  'all things annoying in the world put together into one stupid bitch': 30,
#  'club music': 30,
#  'virginia': 30,
#  'latin rock': 30,
#  'westcoast': 30,
#  'pop country': 30,
#  'straight edge': 30,
#  'german metal': 30,
#  'north carolina': 30,
#  'warp': 30,
#  'hann with gun': 30,
#  'future jazz': 30,
#  'violin': 30,
#  'best': 30,
#  'psych': 30,
#  'rap metal': 29,
#  'tennessee': 29,
#  'punk pop': 29,
#  'hip-hop and rap': 29,
#  'actress': 29,
#  'ireland': 29,
#  'indie-rock': 29,
#  'boy bands': 29,
#  'progressive pop': 29,
#  'louisiana': 29,
#  'g': 29,
#  'lastfmsc': 29,
#  'golden oldies': 29,
#  'musical': 29,
#  'my-love': 29,
#  'lounge chill': 29,
#  'serve chilled': 29,
#  'jazzy flavoured': 29,
#  'acoustic groove': 29,
#  'liquid funk': 29,
#  'radio': 29,
#  'sludge': 29,
#  'hard trance': 29,
#  'latin jazz': 29,
#  'radioparadise': 29,
#  'nice': 29,
#  'bitch': 28,
#  'new metal': 28,
#  'crooner': 28,
#  'talented ladies': 28,
#  'conscious hip-hop': 28,
#  'rocksteady': 28,
#  'singer': 28,
#  'new orleans': 28,
#  'girl power': 28,
#  'riot grrrl': 28,
#  '90s pop': 28,
#  'jam band': 28,
#  'experimental pop': 28,
#  'abstract hip hop': 28,
#  'south': 28,
#  'shit only a retard would listen to': 28,
#  'romantic classical': 28,
#  'korean': 28,
#  'smooth lounge': 28,
#  'lounge electronic': 28,
#  'lounge at home tres': 28,
#  'lounge downtempo': 28,
#  'groove lounge': 28,
#  'my lounge room': 28,
#  'chillair': 28,
#  'acid lounge': 28,
#  'city lounge': 28,
#  'tropcool': 28,
#  'chill chill': 28,
#  'epic lounge': 28,
#  'chillout downtempo': 28,
#  'emusic': 28,
#  'nujazz': 28,
#  'need to rate': 28,
#  'funk metal': 27,
#  'eminem': 27,
#  'god': 27,
#  'g-funk': 27,
#  'girl group': 27,
#  'trap rap': 27,
#  'great': 27,
#  'eighties': 27,
#  'favorite bands': 27,
#  'cool jazz': 27,
#  'yarling': 27,
#  'women': 27,
#  'finland': 27,
#  'poland': 27,
#  'classic soul': 27,
#  'classique': 27,
#  '1': 27,
#  '4': 27,
#  'neosoul': 27,
#  'soulful': 27,
#  'sax': 27,
#  '20th century': 27,
#  'electric blues': 27,
#  'seen in concert': 27,
#  'best of downtempo': 27,
#  'lounge-tech': 27,
#  'lounge uptempo': 27,
#  'best of down tempo': 27,
#  'smoothly sexy sounding': 27,
#  'chillounge1': 27,
#  'sexy sounding': 27,
#  'sweet downtempo': 27,
#  'alternative lounge': 27,
#  'ouahhhhh': 27,
#  'awesome downtempo': 27,
#  'daytrotter': 27,
#  'synthwave': 27,
#  'leftfield': 27,
#  'glo-fi': 27,
#  'spanish rock': 27,
#  'girl': 27,
#  'asciiecho': 27,
#  'download': 27,
#  'deutschland': 27,
#  'dobre bo polskie': 27,
#  'polish music': 27,
#  'rihanna': 26,
#  'pay attention': 26,
#  'kickasstic': 26,
#  'dark wave': 26,
#  'traditional pop': 26,
#  'supergroup': 26,
#  'trumpet': 26,
#  '30s': 26,
#  'eurovision song contest': 26,
#  'art punk': 26,
#  'mexican': 26,
#  'belgian': 26,
#  '2013': 26,
#  '90s rnb': 26,
#  'r': 26,
#  '2': 26,
#  '7': 26,
#  'pop-rap': 26,
#  'greys anatomy': 26,
#  'hamburg': 26,
#  '19th century': 26,
#  'genre:downtempo': 26,
#  'genre: downtempo': 26,
#  'downtempo influences': 26,
#  '1st vine': 26,
#  'lounge at home two': 26,
#  '1st vine acid': 26,
#  'lounge vibe': 26,
#  'chilllounge1': 26,
#  'space disco': 26,
#  'melhores da black music': 26,
#  'most underrated artists': 26,
#  'good stuff': 26,
#  'dansk': 26,
#  'polish rock': 26,
#  'bliss': 26,
#  'lyrical': 25,
#  'terrible': 25,
#  'queens': 25,
#  'poprock': 25,
#  'west coast hip hop': 25,
#  'rap and hip-hop': 25,
#  'brit': 25,
#  'standards': 25,
#  'sub pop': 25,
#  'i': 25,
#  'houston': 25,
#  'girl band': 25,
#  'portland': 25,
#  'mexico': 25,
#  'yung dynasty': 25,
#  '5 stars': 25,
#  'covers': 25,
#  'melodic trance': 25,
#  'k': 25,
#  'e': 25,
#  'mississippi': 25,
#  '20th century classical': 25,
#  'microhouse': 25,
#  'scandinavian girls': 25,
#  'best of chill': 25,
#  'electronic lounge jazz': 25,
#  'jazzy vibes': 25,
#  'lounge groove': 25,
#  'served chilled': 25,
#  'dream trance': 25,
#  'romantica': 25,
#  'the ladies that should sit on my sofa or somewhere else in my flat because they are darlings and oh so lovely': 25,
#  'kgrl': 25,
#  'svenskt': 25,
#  'grady': 25,
#  'midwest rap': 24,
#  'lil wayne': 24,
#  'sleaze rock': 24,
#  'jay-z': 24,
#  'g-unit': 24,
#  'atl': 24,
#  'cabaret': 24,
#  'liverpool': 24,
#  'nwobhm': 24,
#  'jazz funk': 24,
#  'guitarist': 24,
#  'boyband': 24,
#  'belgium': 24,
#  'finnish metal': 24,
#  'bubblegum': 24,
#  'coachella 2008': 24,
#  'ariana grande': 24,
#  'world fusion': 24,
#  'modern': 24,
#  'classic blues': 24,
#  'contemporary christian': 24,
#  'modern composition': 24,
#  'uutta jazzia': 24,
#  'lounge jazz vibe': 24,
#  'denmark': 24,
#  'vagina': 24,
#  'discoverockult': 24,
#  'brit-pop': 24,
#  'lounge music': 24,
#  'miscellaneous': 24,
#  'boring': 23,
#  'pop metal': 23,
#  'pianist': 23,
#  'quiet': 23,
#  'country-rock': 23,
#  'minneapolis': 23,
#  'ed banger': 23,
#  'electropunk': 23,
#  'upbeat': 23,
#  'romanticism': 23,
#  'garage punk': 23,
#  'dreampop': 23,
#  'seen': 23,
#  '9': 23,
#  '6': 23,
#  'ontario': 23,
#  'lame': 23,
#  '3 stars': 23,
#  'jazz-trip': 23,
#  'uuta jazzia': 23,
#  'uutta jazziz': 23,
#  'acid jazz vibe': 23,
#  'jazzy trip': 23,
#  'slow jam': 23,
#  'avant garde': 23,
#  'glitch hop': 23,
#  'listened but not scrobbled': 23,
#  'folk metal': 23,
#  'shady grady': 23,
#  'russian rock': 23,
#  'full-on': 23,
#  'aftermath': 22,
#  'nashville': 22,
#  'beautiful voice': 22,
#  'grammy winner': 22,
#  'montreal': 22,
#  'southern soul': 22,
#  'acoustic guitar': 22,
#  'goregrind': 22,
#  'conscious': 22,
#  'crunkcore': 22,
#  'alabama': 22,
#  'unique': 22,
#  'j': 22,
#  '8': 22,
#  '1960s': 22,
#  'old school soul': 22,
#  'post-classical': 22,
#  ...}

# %% [markdown]
# ### Database

# %%
# connect to PostGreSQL
conn = psycopg2.connect("dbname=spotify user=postgres password=pg")
cursor= conn.cursor()

# %%
# Check current tables
s = "SELECT table_schema, table_name FROM information_schema.tables where table_schema = 'public'"
cursor.execute(s)
list_tables = cursor.fetchall()

# %%
list_tables
# Out:
# [('public', 'artist_song')]

# %%
if len(list_tables) == 1:
    
    # MASTER_ARTIST
    name_Table= "public.master_artist"
    sqlCreateTable_MasterArtist = "create table "+name_Table+" (artist_id varchar(25), artist_name varchar(50), listeners INT, CONSTRAINT artist_id_pkey PRIMARY KEY (artist_id));"
    cursor.execute(sqlCreateTable_MasterArtist)
    
    # ARTIST_SONG
    name_Table= "public.artist_song"
    cols = " (artist_id varchar(25), song_name varchar(100), song_id varchar(25), popularity SMALLINT, duration INT , CONSTRAINT artist_song_id_pkey PRIMARY KEY (song_id, artist_id));"
    sqlCreateTable_ArtistSong = "create table " + name_Table + cols
    cursor.execute(sqlCreateTable_ArtistSong)
    
    # COUNTRY_ARTIST
    name_Table= "public.country_artist"
    sqlCreateTable_MasterArtist = "create table "+name_Table+" (artist_id varchar(25), country varchar(50), listeners INT, CONSTRAINT artist_id_pkey PRIMARY KEY (artist_id));"
    cursor.execute(sqlCreateTable_MasterArtist)
    
    #Commit changes
    conn.commit()

# %%
def levenshtein(s1, s2):
    """
    Function that implements roughly an approximation of the Levenshtein algorithm
    for string similarity. Is a distance metric, hence, the closer to 0, the most similar
    the strings will be
    """
    if len(s1) < len(s2):
        s1, s2 = s2, s1

    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]/float(len(s1))

# %%
client_id = "348f94d3a73241188b2a89c91e1cfaee"
client_secret = "b5b29b040ab843cf842cf4eb875caff1"

# %%
dict_artists = {}
master_artist = {}

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

# %% [markdown]
# ### Get Artist ID

# %%
artist_list_query = ["Sia", "Macklemore", "Avicii"]
dict_artist_metadata = {}

# %%
for name_artist_query in artist_list_query:
    
    # Prepare string to search in Spotipy
    name = '{' + name_artist_query + '}'
    
    #Avoid gigant artists names
    if len(name_artist_query) >= 50:
        continue
    
    #search query
    result = sp.search(name) 
    
    # Create a dictionary entrance for that artist
    # Avoid doing an artist twice
    if name_artist_query not in dict_artist_metadata:
        dict_artist_metadata[name_artist_query] = {}
    else:
        continue
        

    #Iterate through all the tracks of that search query
    tracks_artist_query = result["tracks"]["items"]
    found = 0

    for track in tracks_artist_query:
        
        #Get the artist info for the tracks
        various_artists = track["artists"]
        
        # Iterate through a list of artists (a track can have many artists)
        for var_art in various_artists:

            # If the name is very close to the queried one, get the ID and uri and quit loop
            artist_similarity = levenshtein(name_artist_query, var_art["name"])
            if artist_similarity < 0.1:
                found = 1 #it has found a similar artist as written in the query
                break

        # If it has found that artist get the ID and URI
        if found == 1:
            dict_artist_metadata[name_artist_query]["uri"] = var_art["uri"]
            dict_artist_metadata[name_artist_query]["artist_id"]  = var_art["id"]
            dict_artist_metadata[name_artist_query]["name_artist"]  = var_art["name"]
            break #quit the loop

# %%
dict_artist_metadata
# Out:
# {'Sia': {'uri': 'spotify:artist:5WUlDfRSoLAfcVSX1WnrxN',
#   'artist_id': '5WUlDfRSoLAfcVSX1WnrxN',
#   'name_artist': 'Sia'},
#  'Macklemore': {'uri': 'spotify:artist:3JhNCzhSMTxs9WLGJJxWOY',
#   'artist_id': '3JhNCzhSMTxs9WLGJJxWOY',
#   'name_artist': 'Macklemore'},
#  'Avicii': {'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6',
#   'artist_id': '1vCWHaC5f2uS3yhpwWbIA6',
#   'name_artist': 'Avicii'}}

# %% [markdown]
# ### Master Table - Artist

# %%
master_artist = {}
for k, v in dict_artist_metadata.items():
    master_artist[v["artist_id"]] = v["name_artist"]

# %%
def insert_into_master(dict_input):
    query_insert = f"insert into master_artist (artist_id, artist_name) VALUES "
    values_str = ""
    for k,v in dict_input.items():
        values_str = ",".join((values_str, f"('{k}','{v}')"))
    return query_insert + values_str[1:] + " ON CONFLICT DO NOTHING;"

# %%
query_master = insert_into_master(master_artist)
cursor.execute(query_master)
conn.commit()

# %% [markdown]
# # Top Tracks

# %%
top_tracks = sp.artist_top_tracks(uri)

# %% [markdown]
# ### Top 10 Songs for Artist Table

# %%
#Dictionary for each artist
dict_artists[artist_id] = []

# For each track
if "tracks" in top_tracks:
    if len(top_tracks["tracks"]):
        for track in top_tracks["tracks"]:
            
            dict_track = dict()
            # SONG - Properties - Initializer
            dict_track["name"] = ""
            dict_track["duration"]  = 0
            dict_track["popularity"] = 0
            dict_track["song_id"] = ""
            
            # Check the number of artists featuring the song
            # Add to their dictionary the features of the song
            # for them too
            
            # Create a set for the feat. artists
            set_featuring_artists = set()
            
            if "artists" in track:
                
                # Loop through all artists of a song
                for art_dict in track["artists"]:
                    
                    if "name" in art_dict and "id" in art_dict:
                        
                        # Get the id of that artist 
                        id_feat_artist = art_dict["id"]
                        name_feat_artist = art_dict["name"]
                        
                        #If the artist is different from the query one add it
                        # to both the dict_artist and the master_artist
                        if id_feat_artist != artist_id:
                            
                            # Add that feat. artist to the set
                            set_featuring_artists.add(id_feat_artist)
                            
                            # Add that feat. artist to the master of artists
                            master_artist[id_feat_artist] = name_feat_artist
                    
            # SONG - Properties - Track
            # Song name
            if "name" in track:
                dict_track["name"] = track["name"]
            
            # Duration
            if "duration_ms" in track:
                dict_track["duration"]  = track["duration_ms"]
            
            #Popularity
            if "popularity" in track:
                dict_track["popularity"] = track["popularity"]
                
            # Song ID
            if "id" in track:
                dict_track["song_id"] = track["id"]
                
            # Write the dictionary of song properties for the main artist
            dict_artists[artist_id].append(dict_track)
            
            # Write the dictionary of song properties for each of the feat. artists
            list_featuring_artists = list(set_featuring_artists)
            for i_id_feat_artist in list_featuring_artists:
                
                # If that artist is not yet in the dictionary of artists, add it:
                if i_id_feat_artist not in dict_artists:
                    dict_artists[i_id_feat_artist] = []
                dict_artists[i_id_feat_artist].append(dict_track)

# %%
dict_artists
# Out:
# {'1Cs0zKBU1kc0i8ypK3B9ai': [{'name': 'Titanium (feat. Sia)',
#    'duration': 245040,
#    'popularity': 66,
#    'song_id': '0lHAMNU8RGiIObScrsRgmP'},
#   {'name': 'Instagram',
#    'duration': 184558,
#    'popularity': 78,
#    'song_id': '0U6bQIAh6MCGo1xjbIIx2S'},
#   {'name': 'Say My Name',
#    'duration': 198946,
#    'popularity': 66,
#    'song_id': '3MoV1UsAJmz64LHqyiRMp0'},
#   {'name': "Better When You're Gone",
#    'duration': 192402,
#    'popularity': 74,
#    'song_id': '4Tvw0lweq9l2JPQKFbpbBQ'},
#   {'name': 'Conversations in the Dark - John Legend vs. David Guetta',
#    'duration': 210236,
#    'popularity': 74,
#    'song_id': '20d27F17AZOxTJOEHAVK2Y'},
#   {'name': 'Flames',
#    'duration': 195000,
#    'popularity': 54,
#    'song_id': '3tTYxjYYcXFqFXA0AZ1Fav'},
#   {'name': 'Sexy Bitch (feat. Akon)',
#    'duration': 195853,
#    'popularity': 61,
#    'song_id': '0uXO2GrNiIb1xHT9LUdxZE'},
#   {'name': 'Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack)',
#    'duration': 192560,
#    'popularity': 61,
#    'song_id': '5b2bu6yyATC1zMXDGScJ2d'},
#   {'name': 'Like I Do',
#    'duration': 201560,
#    'popularity': 54,
#    'song_id': '03IBnHJvOQBr4dy3RguAph'},
#   {'name': "Stay (Don't Go Away) [feat. Raye]",
#    'duration': 185942,
#    'popularity': 71,
#    'song_id': '4YhN72dRYL2Z3MsaKyT7rS'}],
#  '2HkAI0YrEcgoR8QdaURqhO': [{'name': 'Instagram',
#    'duration': 184558,
#    'popularity': 78,
#    'song_id': '0U6bQIAh6MCGo1xjbIIx2S'}],
#  '1GDbiv3spRmZ1XdM1jQbT7': [{'name': 'Instagram',
#    'duration': 184558,
#    'popularity': 78,
#    'song_id': '0U6bQIAh6MCGo1xjbIIx2S'}],
#  '4pwXiI7Z5ZStkgKowZyoKi': [{'name': 'Instagram',
#    'duration': 184558,
#    'popularity': 78,
#    'song_id': '0U6bQIAh6MCGo1xjbIIx2S'}],
#  '3wtMPMvPtiFylbnNXF6CAj': [{'name': 'Instagram',
#    'duration': 184558,
#    'popularity': 78,
#    'song_id': '0U6bQIAh6MCGo1xjbIIx2S'}],
#  '4VMYDCV2IEDYJArk749S6m': [{'name': 'Instagram',
#    'duration': 184558,
#    'popularity': 78,
#    'song_id': '0U6bQIAh6MCGo1xjbIIx2S'}],
#  '73jBynjsVtofjRpdpRAJGk': [{'name': 'Instagram',
#    'duration': 184558,
#    'popularity': 78,
#    'song_id': '0U6bQIAh6MCGo1xjbIIx2S'}],
#  '1vyhD5VmyZ7KMfW5gqLgo5': [{'name': 'Say My Name',
#    'duration': 198946,
#    'popularity': 66,
#    'song_id': '3MoV1UsAJmz64LHqyiRMp0'}],
#  '64M6ah0SkkRsnPGtGiRAbb': [{'name': 'Say My Name',
#    'duration': 198946,
#    'popularity': 66,
#    'song_id': '3MoV1UsAJmz64LHqyiRMp0'},
#   {'name': 'Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack)',
#    'duration': 192560,
#    'popularity': 61,
#    'song_id': '5b2bu6yyATC1zMXDGScJ2d'}],
#  '00TKPo9MxwZ0j4ooveIxWZ': [{'name': "Better When You're Gone",
#    'duration': 192402,
#    'popularity': 74,
#    'song_id': '4Tvw0lweq9l2JPQKFbpbBQ'}],
#  '4mHAu7NX2UNsnGXjviBD9e': [{'name': "Better When You're Gone",
#    'duration': 192402,
#    'popularity': 74,
#    'song_id': '4Tvw0lweq9l2JPQKFbpbBQ'},
#   {'name': 'Like I Do',
#    'duration': 201560,
#    'popularity': 54,
#    'song_id': '03IBnHJvOQBr4dy3RguAph'}],
#  '5y2Xq6xcjJb2jVM54GHK3t': [{'name': 'Conversations in the Dark - John Legend vs. David Guetta',
#    'duration': 210236,
#    'popularity': 74,
#    'song_id': '20d27F17AZOxTJOEHAVK2Y'}],
#  '5WUlDfRSoLAfcVSX1WnrxN': [{'name': 'Flames',
#    'duration': 195000,
#    'popularity': 54,
#    'song_id': '3tTYxjYYcXFqFXA0AZ1Fav'}],
#  '0z4gvV4rjIZ9wHck67ucSV': [{'name': 'Sexy Bitch (feat. Akon)',
#    'duration': 195853,
#    'popularity': 61,
#    'song_id': '0uXO2GrNiIb1xHT9LUdxZE'}],
#  '0hCNtLu0JehylgoiP8L4Gh': [{'name': 'Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack)',
#    'duration': 192560,
#    'popularity': 61,
#    'song_id': '5b2bu6yyATC1zMXDGScJ2d'}],
#  '4D75GcNG95ebPtNvoNVXhz': [{'name': 'Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack)',
#    'duration': 192560,
#    'popularity': 61,
#    'song_id': '5b2bu6yyATC1zMXDGScJ2d'}],
#  '60d24wfXkVzDSfLS6hyCjZ': [{'name': 'Like I Do',
#    'duration': 201560,
#    'popularity': 54,
#    'song_id': '03IBnHJvOQBr4dy3RguAph'}],
#  '5KKpBU5eC2tJDzf0wmlRp2': [{'name': "Stay (Don't Go Away) [feat. Raye]",
#    'duration': 185942,
#    'popularity': 71,
#    'song_id': '4YhN72dRYL2Z3MsaKyT7rS'}]}

# %%
master_artist
# Out:
# {'1Cs0zKBU1kc0i8ypK3B9ai': 'David Guetta',
#  '73jBynjsVtofjRpdpRAJGk': 'Dimitri Vegas & Like Mike',
#  '4VMYDCV2IEDYJArk749S6m': 'Daddy Yankee',
#  '3wtMPMvPtiFylbnNXF6CAj': 'Afro Bros',
#  '1GDbiv3spRmZ1XdM1jQbT7': 'Natti Natasha',
#  '2HkAI0YrEcgoR8QdaURqhO': 'Dimitri Vegas',
#  '4pwXiI7Z5ZStkgKowZyoKi': 'Like Mike',
#  '64M6ah0SkkRsnPGtGiRAbb': 'Bebe Rexha',
#  '1vyhD5VmyZ7KMfW5gqLgo5': 'J Balvin',
#  '4mHAu7NX2UNsnGXjviBD9e': 'Brooks',
#  '00TKPo9MxwZ0j4ooveIxWZ': 'Loote',
#  '5y2Xq6xcjJb2jVM54GHK3t': 'John Legend',
#  '5WUlDfRSoLAfcVSX1WnrxN': 'Sia',
#  '0z4gvV4rjIZ9wHck67ucSV': 'Akon',
#  '4D75GcNG95ebPtNvoNVXhz': 'Afrojack',
#  '0hCNtLu0JehylgoiP8L4Gh': 'Nicki Minaj',
#  '60d24wfXkVzDSfLS6hyCjZ': 'Martin Garrix',
#  '5KKpBU5eC2tJDzf0wmlRp2': 'RAYE'}

# %% [markdown]
# ## Upload dict_artist and master_artist to Postgresql

# %%
a = ("1","2")
''.join(a)
# Out:
# '12'

# %%
-- Table: public.artists_1

-- DROP TABLE public.artists_1;

CREATE TABLE public.artists_1
(
    artist_id "char" NOT NULL,
    artist_name "char",
    CONSTRAINT artists_1_pkey PRIMARY KEY (artist_id)
)

TABLESPACE pg_default;

ALTER TABLE public.artists_1
    OWNER to postgres;
