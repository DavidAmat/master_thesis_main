# %% [markdown]
# # Dataset Creation
#
# For the sake of notation, Main_Artists are the ones found in the kworb website, whereas Other_Artists are other artists that appear on Spotify but that do not appear in that webiste.

# %%
import pandas as pd
import sys
import numpy as np
import os
import requests
import datetime
import base64
import re
from collections import Counter
import psycopg2
import tqdm
from bs4 import BeautifulSoup

# %%
# We create a utils file with a class to store the basic commands and client ID for the Spotify API
from aux_utils import spotify_utils

# %% [markdown]
# #### Spotify API connection

# %%
# Instantiate the class
sp_ut = spotify_utils()

# Use the method connect to connect with the credentials
sp = sp_ut.connect()

# %%
sp.search("Ramin Djawadi")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Ramin+Djawadi&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Ia3TzAjzWw0Tdspy9Fwgg'},
#      'href': 'https://api.spotify.com/v1/albums/2Ia3TzAjzWw0Tdspy9Fwgg',
#      'id': '2Ia3TzAjzWw0Tdspy9Fwgg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e4f028aed6760c0c7f1eb0ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e4f028aed6760c0c7f1eb0ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e4f028aed6760c0c7f1eb0ca',
#        'width': 64}],
#      'name': 'Game Of Thrones: Season 6 (Music from the HBO Series)',
#      'release_date': '2016-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:2Ia3TzAjzWw0Tdspy9Fwgg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 589094,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1600338'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1SbsbLsUMnAKWHx1zAV6ER'},
#     'href': 'https://api.spotify.com/v1/tracks/1SbsbLsUMnAKWHx1zAV6ER',
#     'id': '1SbsbLsUMnAKWHx1zAV6ER',
#     'is_local': False,
#     'name': 'Light of the Seven',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/88eeb34c8ff3286be682569d7404abceaf73dad0?cid=348f94d3a73241188b2a89c91e1cfaee',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1SbsbLsUMnAKWHx1zAV6ER'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3AOeatEAPjy1CKtdkaXaDq'},
#      'href': 'https://api.spotify.com/v1/albums/3AOeatEAPjy1CKtdkaXaDq',
#      'id': '3AOeatEAPjy1CKtdkaXaDq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273536f3b6f6b46e6e97742673b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02536f3b6f6b46e6e97742673b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851536f3b6f6b46e6e97742673b',
#        'width': 64}],
#      'name': 'Game Of Thrones: Season 8 (Music from the HBO Series)',
#      'release_date': '2019-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:3AOeatEAPjy1CKtdkaXaDq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 530532,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1900244'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1aDklx1GaBqHFowCzz63wU'},
#     'href': 'https://api.spotify.com/v1/tracks/1aDklx1GaBqHFowCzz63wU',
#     'id': '1aDklx1GaBqHFowCzz63wU',
#     'is_local': False,
#     'name': 'The Night King',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/310a325dc37f428a2b4738f1553474ef50625a6b?cid=348f94d3a73241188b2a89c91e1cfaee',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:1aDklx1GaBqHFowCzz63wU'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4h8YNfTlnKKwqImHRZwhBg'},
#      'href': 'https://api.spotify.com/v1/albums/4h8YNfTlnKKwqImHRZwhBg',
#      'id': '4h8YNfTlnKKwqImHRZwhBg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27300c70c200f7a397375da6b5f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0200c70c200f7a397375da6b5f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485100c70c200f7a397375da6b5f',
#        'width': 64}],
#      'name': 'Westworld: Season 3 (Music From The HBO Series)',
#      'release_date': '2020-05-03',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:4h8YNfTlnKKwqImHRZwhBg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 331594,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR2000107'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/29mrsJanlVWcZDe9gP6NJ6'},
#     'href': 'https://api.spotify.com/v1/tracks/29mrsJanlVWcZDe9gP6NJ6',
#     'id': '29mrsJanlVWcZDe9gP6NJ6',
#     'is_local': False,
#     'name': 'Wicked Games',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3683bb9aa28fd9bf02cd83c7b0326a9b1b575ff7?cid=348f94d3a73241188b2a89c91e1cfaee',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:29mrsJanlVWcZDe9gP6NJ6'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/41zMFsCjcGenYKVJYUXU2n'},
#      'href': 'https://api.spotify.com/v1/albums/41zMFsCjcGenYKVJYUXU2n',
#      'id': '41zMFsCjcGenYKVJYUXU2n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362be9b16adb2e32aed9bda26',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262be9b16adb2e32aed9bda26',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162be9b16adb2e32aed9bda26',
#        'width': 64}],
#      'name': 'Game Of Thrones: Season 3 (Music from the HBO Series)',
#      'release_date': '2013-06-04',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:41zMFsCjcGenYKVJYUXU2n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 170560,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1300355'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1vPEPhmGDnp8RR6GCBozaa'},
#     'href': 'https://api.spotify.com/v1/tracks/1vPEPhmGDnp8RR6GCBozaa',
#     'id': '1vPEPhmGDnp8RR6GCBozaa',
#     'is_local': False,
#     'name': 'A Lannister Always Pays His Debts',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/43d967066f07ecdf7daded0bdc521adc73a0f07a?cid=348f94d3a73241188b2a89c91e1cfaee',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1vPEPhmGDnp8RR6GCBozaa'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5P9JZJW0itEaDK5RfWiSuZ'},
#      'href': 'https://api.spotify.com/v1/albums/5P9JZJW0itEaDK5RfWiSuZ',
#      'id': '5P9JZJW0itEaDK5RfWiSuZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273239a1395e4d595efc28af924',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02239a1395e4d595efc28af924',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851239a1395e4d595efc28af924',
#        'width': 64}],
#      'name': 'Game Of Thrones (Music From The HBO Series)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:5P9JZJW0itEaDK5RfWiSuZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 106280,
#     'explicit': False,
#     'external_ids': {'isrc': 'US3M51109701'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2q6fxAvSpqXR4jx9Ne7RGz'},
#     'href': 'https://api.spotify.com/v1/tracks/2q6fxAvSpqXR4jx9Ne7RGz',
#     'id': '2q6fxAvSpqXR4jx9Ne7RGz',
#     'is_local': False,
#     'name': 'Main Title - From The "Game Of Thrones" Soundtrack',
#     'popularity': 61,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2q6fxAvSpqXR4jx9Ne7RGz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/43pttVYo7IjBvive3uebVF'},
#      'href': 'https://api.spotify.com/v1/albums/43pttVYo7IjBvive3uebVF',
#      'id': '43pttVYo7IjBvive3uebVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738129e2367c42697ba06a5a2e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028129e2367c42697ba06a5a2e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518129e2367c42697ba06a5a2e',
#        'width': 64}],
#      'name': 'Westworld: Season 1 (Music from the HBO Series)',
#      'release_date': '2016-12-05',
#      'release_date_precision': 'day',
#      'total_tracks': 34,
#      'type': 'album',
#      'uri': 'spotify:album:43pttVYo7IjBvive3uebVF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 101461,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1600920'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2sw8teIvVMRZKKYD5p795f'},
#     'href': 'https://api.spotify.com/v1/tracks/2sw8teIvVMRZKKYD5p795f',
#     'id': '2sw8teIvVMRZKKYD5p795f',
#     'is_local': False,
#     'name': 'Main Title Theme - Westworld',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/836b9da51cefcb07a9af8ef8d7a99479073d43b5?cid=348f94d3a73241188b2a89c91e1cfaee',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2sw8teIvVMRZKKYD5p795f'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/43pttVYo7IjBvive3uebVF'},
#      'href': 'https://api.spotify.com/v1/albums/43pttVYo7IjBvive3uebVF',
#      'id': '43pttVYo7IjBvive3uebVF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738129e2367c42697ba06a5a2e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028129e2367c42697ba06a5a2e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518129e2367c42697ba06a5a2e',
#        'width': 64}],
#      'name': 'Westworld: Season 1 (Music from the HBO Series)',
#      'release_date': '2016-12-05',
#      'release_date_precision': 'day',
#      'total_tracks': 34,
#      'type': 'album',
#      'uri': 'spotify:album:43pttVYo7IjBvive3uebVF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 344017,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1600922'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6rSVuRt7xl4GsEQv4tphSl'},
#     'href': 'https://api.spotify.com/v1/tracks/6rSVuRt7xl4GsEQv4tphSl',
#     'id': '6rSVuRt7xl4GsEQv4tphSl',
#     'is_local': False,
#     'name': 'Paint It, Black',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/50b507df578e2b26c8f7a6e1e198e74382bbe27b?cid=348f94d3a73241188b2a89c91e1cfaee',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6rSVuRt7xl4GsEQv4tphSl'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5P9JZJW0itEaDK5RfWiSuZ'},
#      'href': 'https://api.spotify.com/v1/albums/5P9JZJW0itEaDK5RfWiSuZ',
#      'id': '5P9JZJW0itEaDK5RfWiSuZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273239a1395e4d595efc28af924',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02239a1395e4d595efc28af924',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851239a1395e4d595efc28af924',
#        'width': 64}],
#      'name': 'Game Of Thrones (Music From The HBO Series)',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:5P9JZJW0itEaDK5RfWiSuZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 187280,
#     'explicit': False,
#     'external_ids': {'isrc': 'US3M51109703'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5n44Y1e8exufbm9mmAvopf'},
#     'href': 'https://api.spotify.com/v1/tracks/5n44Y1e8exufbm9mmAvopf',
#     'id': '5n44Y1e8exufbm9mmAvopf',
#     'is_local': False,
#     'name': 'Goodbye Brother - From The "Game Of Thrones" Soundtrack',
#     'popularity': 56,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5n44Y1e8exufbm9mmAvopf'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4U6mv2dfPwbp3NQlq2CSaj'},
#      'href': 'https://api.spotify.com/v1/albums/4U6mv2dfPwbp3NQlq2CSaj',
#      'id': '4U6mv2dfPwbp3NQlq2CSaj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c7776da1be35430804c80c42',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c7776da1be35430804c80c42',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c7776da1be35430804c80c42',
#        'width': 64}],
#      'name': 'Westworld: Season 2 (Music From the HBO Series)',
#      'release_date': '2018-06-25',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:4U6mv2dfPwbp3NQlq2CSaj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 204628,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1800187'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0OSfLPEQb1PLL0Q0C2xZVE'},
#     'href': 'https://api.spotify.com/v1/tracks/0OSfLPEQb1PLL0Q0C2xZVE',
#     'id': '0OSfLPEQb1PLL0Q0C2xZVE',
#     'is_local': False,
#     'name': 'Heart-Shaped Box (Orchestral)',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b22a2f9b14eeab0e928e4faeab3ec0735d62448d?cid=348f94d3a73241188b2a89c91e1cfaee',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:0OSfLPEQb1PLL0Q0C2xZVE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3AOeatEAPjy1CKtdkaXaDq'},
#      'href': 'https://api.spotify.com/v1/albums/3AOeatEAPjy1CKtdkaXaDq',
#      'id': '3AOeatEAPjy1CKtdkaXaDq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273536f3b6f6b46e6e97742673b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02536f3b6f6b46e6e97742673b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851536f3b6f6b46e6e97742673b',
#        'width': 64}],
#      'name': 'Game Of Thrones: Season 8 (Music from the HBO Series)',
#      'release_date': '2019-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:3AOeatEAPjy1CKtdkaXaDq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0BEI7i5sgUuivcfwXLzFmM'},
#       'href': 'https://api.spotify.com/v1/artists/0BEI7i5sgUuivcfwXLzFmM',
#       'id': '0BEI7i5sgUuivcfwXLzFmM',
#       'name': 'Serj Tankian',
#       'type': 'artist',
#       'uri': 'spotify:artist:0BEI7i5sgUuivcfwXLzFmM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 224305,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1900248'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0CHvs1UmxA90B2apIpbWCC'},
#     'href': 'https://api.spotify.com/v1/tracks/0CHvs1UmxA90B2apIpbWCC',
#     'id': '0CHvs1UmxA90B2apIpbWCC',
#     'is_local': False,
#     'name': 'The Rains of Castamere',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a8aa24056b57474e8b5fabb59414da8dc1293a24?cid=348f94d3a73241188b2a89c91e1cfaee',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0CHvs1UmxA90B2apIpbWCC'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Ramin+Djawadi&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 1116}}

# %%
sp.artist_related_artists("6XYRpcgPIK9OejoVzA7PbC")
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eAm5IYwnH7uTX5EBT9sbi'},
#    'followers': {'href': None, 'total': 19885},
#    'genres': ['cantautor',
#     'catalan folk',
#     'indie catala',
#     'rock catala',
#     'rumba',
#     'rumba catalana'],
#    'href': 'https://api.spotify.com/v1/artists/3eAm5IYwnH7uTX5EBT9sbi',
#    'id': '3eAm5IYwnH7uTX5EBT9sbi',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/eca25266e9888a095df408c60d35029c5fac083e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/08102a8884ff955a7488a9d7a5cbc084d65dfd7b',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/3cb51dd489be53c7ef41605b72e4ecf66d28d722',
#      'width': 160}],
#    'name': 'Gertrudis',
#    'popularity': 47,
#    'type': 'artist',
#    'uri': 'spotify:artist:3eAm5IYwnH7uTX5EBT9sbi'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0OVfimlbekXaMrP8IoCzHJ'},
#    'followers': {'href': None, 'total': 54219},
#    'genres': ['cantautor', 'catalan folk', 'indie catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/0OVfimlbekXaMrP8IoCzHJ',
#    'id': '0OVfimlbekXaMrP8IoCzHJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/3ea7cd45e8ecc4274bf3d17499456d71d4c9fef9',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/23dab638c4829c76548bb27e99b247a11724144c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/f624f5919cac0d1926cd848955fd7aff8b3be9a7',
#      'width': 160}],
#    'name': 'Els Pets',
#    'popularity': 48,
#    'type': 'artist',
#    'uri': 'spotify:artist:0OVfimlbekXaMrP8IoCzHJ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7BdgXLhynRQk78pKkhAsAR'},
#    'followers': {'href': None, 'total': 49541},
#    'genres': ['indie catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/7BdgXLhynRQk78pKkhAsAR',
#    'id': '7BdgXLhynRQk78pKkhAsAR',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/74d77f543cdf5b5782ba3aa253452288bea1705f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/0ba8fb7a6ba49a4c377c042a374ed6344c1f8cb1',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/3e8608ada52150ffa2678bf987793d52bd31ea26',
#      'width': 160}],
#    'name': 'Buhos',
#    'popularity': 52,
#    'type': 'artist',
#    'uri': 'spotify:artist:7BdgXLhynRQk78pKkhAsAR'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0op3EnoEZ0jQY13sbyoSo2'},
#    'followers': {'href': None, 'total': 87584},
#    'genres': ['cantautor', 'indie catala', 'rock catala', 'spanish folk'],
#    'href': 'https://api.spotify.com/v1/artists/0op3EnoEZ0jQY13sbyoSo2',
#    'id': '0op3EnoEZ0jQY13sbyoSo2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/5fefa83549b13c807650dae95b3ec0b0762e56f9',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/73cbc29afac44030c9aa3f5358a162279e6a5a29',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/66ef75bd9e269faa23643254fd1cbad9b5852454',
#      'width': 160}],
#    'name': 'Els Amics De Les Arts',
#    'popularity': 52,
#    'type': 'artist',
#    'uri': 'spotify:artist:0op3EnoEZ0jQY13sbyoSo2'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5cl9YjDDdgrN50CJzZO6er'},
#    'followers': {'href': None, 'total': 15725},
#    'genres': ['cantautor',
#     'cantautor catala',
#     'catalan folk',
#     'indie catala',
#     'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/5cl9YjDDdgrN50CJzZO6er',
#    'id': '5cl9YjDDdgrN50CJzZO6er',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/6fd41b1012fb73e672f09b875532e86a428c0d7e',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/2eba995a28c8daec7342b5d2ac8733334df5f60c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/5f8a50acb8e04f2e357156b869577c3ec56bc934',
#      'width': 160}],
#    'name': 'Cesk Freixas',
#    'popularity': 48,
#    'type': 'artist',
#    'uri': 'spotify:artist:5cl9YjDDdgrN50CJzZO6er'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0InCPtI0kadS7s3cZrcbbY'},
#    'followers': {'href': None, 'total': 102521},
#    'genres': ['cantautor', 'indie catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/0InCPtI0kadS7s3cZrcbbY',
#    'id': '0InCPtI0kadS7s3cZrcbbY',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/3332addb6f4bdf450350968ddeec081f2e631ebf',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/07ae4212e9bbd098e9f0730bb492c6d981bc60b5',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/8a924b70acf73b2f1bf6ab84cc1f72849872697a',
#      'width': 160}],
#    'name': 'Els Catarres',
#    'popularity': 52,
#    'type': 'artist',
#    'uri': 'spotify:artist:0InCPtI0kadS7s3cZrcbbY'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3LvDuQ0lHuIaNzW3Sv3NVO'},
#    'followers': {'href': None, 'total': 44150},
#    'genres': ['indie catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/3LvDuQ0lHuIaNzW3Sv3NVO',
#    'id': '3LvDuQ0lHuIaNzW3Sv3NVO',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/93224b270bf4c6fd542d1762b3e23fd7c59a0096',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/7245bb452c974bee019483b89d63c752dda881e1',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/dcb25fcd91f8c4e06a8306a535c765d3e3ce2ee5',
#      'width': 160}],
#    'name': 'Blaumut',
#    'popularity': 50,
#    'type': 'artist',
#    'uri': 'spotify:artist:3LvDuQ0lHuIaNzW3Sv3NVO'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3bSjpDHDskBXS2z5WuaXaq'},
#    'followers': {'href': None, 'total': 16943},
#    'genres': ['cantautor', 'indie catala', 'reggae catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/3bSjpDHDskBXS2z5WuaXaq',
#    'id': '3bSjpDHDskBXS2z5WuaXaq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/f79bff0b430cf698b0b8f2a11d9f2fdfa01c7c36',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/897a2c477b0bf699b0f7b85ede8533bbf0fc8603',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/6cb801915b98d2f614ac82bb091ae83d0b0bae25',
#      'width': 160}],
#    'name': "Pirat's Sound Sistema",
#    'popularity': 38,
#    'type': 'artist',
#    'uri': 'spotify:artist:3bSjpDHDskBXS2z5WuaXaq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/53QBC13AaAEh9AgmUFx5CH'},
#    'followers': {'href': None, 'total': 14418},
#    'genres': ['cantautor',
#     'catalan folk',
#     'indie catala',
#     'mestissatge',
#     'reggae catala',
#     'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/53QBC13AaAEh9AgmUFx5CH',
#    'id': '53QBC13AaAEh9AgmUFx5CH',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/76682b33579c373ce40b51fe58f08bbe34c3b66f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/4cc8fb807803c2787742b6cee0660a084db513ab',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/35dcf07d65fb9048bbf63b556ace5ee91c2af2f6',
#      'width': 160}],
#    'name': 'Strombers',
#    'popularity': 39,
#    'type': 'artist',
#    'uri': 'spotify:artist:53QBC13AaAEh9AgmUFx5CH'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ix9GNTGIUIFBpPC6K0QeP'},
#    'followers': {'href': None, 'total': 50522},
#    'genres': ['cantautor', 'catalan folk', 'indie catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/7Ix9GNTGIUIFBpPC6K0QeP',
#    'id': '7Ix9GNTGIUIFBpPC6K0QeP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/e2b85624d3cfa1c3d528ec85c005772835f7a3d4',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/dbdeb409b988300b004de4fb204e472c8e88df04',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/3484ecf840a7d96f10f61b4a14ed9a1998bc9b37',
#      'width': 160}],
#    'name': "Lax'n'Busto",
#    'popularity': 46,
#    'type': 'artist',
#    'uri': 'spotify:artist:7Ix9GNTGIUIFBpPC6K0QeP'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fx0EsmjDotI8Vq4daoB2g'},
#    'followers': {'href': None, 'total': 8513},
#    'genres': ['cantautor',
#     'cantautor catala',
#     'catalan folk',
#     'indie catala',
#     'musica valenciana',
#     'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/2fx0EsmjDotI8Vq4daoB2g',
#    'id': '2fx0EsmjDotI8Vq4daoB2g',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/7a3b2f045f25b42a996939581a23ea7515d7a86b',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/76ac945144111fb39fd9bec54cad8c893cc88370',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/544dcfddb3c04c0eb3b74af3d840aaa929054997',
#      'width': 160}],
#    'name': 'Pau Alabajos',
#    'popularity': 32,
#    'type': 'artist',
#    'uri': 'spotify:artist:2fx0EsmjDotI8Vq4daoB2g'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3V8Ri9UHBCg1YeAwfqW6yz'},
#    'followers': {'href': None, 'total': 7225},
#    'genres': ['mestissatge', 'reggae catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/3V8Ri9UHBCg1YeAwfqW6yz',
#    'id': '3V8Ri9UHBCg1YeAwfqW6yz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/1d6eadf379b36d130d6fbaeee4c1bd964f06cb4a',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/dbbc6e54228e8c83b887d22e7145f36f612eb978',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/aa84ccaa3925557f320dab61e0c4f7ed89ee325d',
#      'width': 160}],
#    'name': 'XEIC!',
#    'popularity': 31,
#    'type': 'artist',
#    'uri': 'spotify:artist:3V8Ri9UHBCg1YeAwfqW6yz'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/798kDjwOnvYR4iLHoDR3Gl'},
#    'followers': {'href': None, 'total': 30553},
#    'genres': ['cantautor', 'catalan folk', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/798kDjwOnvYR4iLHoDR3Gl',
#    'id': '798kDjwOnvYR4iLHoDR3Gl',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/5f66fa0155809c5ab6a0f19b529e6cffd01eb614',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/0db2b43f41fcb7c96a85758890db5aa5e6822ac8',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/a694419eab9137d00152a672daa1f8bb25f837c8',
#      'width': 160}],
#    'name': 'Gossos',
#    'popularity': 41,
#    'type': 'artist',
#    'uri': 'spotify:artist:798kDjwOnvYR4iLHoDR3Gl'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0T4rfoOZaBOSDm6DyGVGzF'},
#    'followers': {'href': None, 'total': 12845},
#    'genres': ['cantautor',
#     'catalan folk',
#     'indie catala',
#     'punk catala',
#     'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/0T4rfoOZaBOSDm6DyGVGzF',
#    'id': '0T4rfoOZaBOSDm6DyGVGzF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ddc35fe2afcbcdf98f2f87eb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ddc35fe2afcbcdf98f2f87eb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ddc35fe2afcbcdf98f2f87eb',
#      'width': 64}],
#    'name': 'Sangtraït',
#    'popularity': 32,
#    'type': 'artist',
#    'uri': 'spotify:artist:0T4rfoOZaBOSDm6DyGVGzF'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/78LSyERttuORro7Rz8ar3L'},
#    'followers': {'href': None, 'total': 18185},
#    'genres': ['cantautor',
#     'catalan folk',
#     'indie catala',
#     'mestissatge',
#     'rock catala',
#     'rumba',
#     'rumba catalana'],
#    'href': 'https://api.spotify.com/v1/artists/78LSyERttuORro7Rz8ar3L',
#    'id': '78LSyERttuORro7Rz8ar3L',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27392d5b2b52f0445d8d4cbca72',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0292d5b2b52f0445d8d4cbca72',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485192d5b2b52f0445d8d4cbca72',
#      'width': 64}],
#    'name': 'La Troba Kung-Fú',
#    'popularity': 37,
#    'type': 'artist',
#    'uri': 'spotify:artist:78LSyERttuORro7Rz8ar3L'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0luDJsRYWbHW2Sj1I5TPrE'},
#    'followers': {'href': None, 'total': 58812},
#    'genres': ['musica valenciana', 'reggae catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/0luDJsRYWbHW2Sj1I5TPrE',
#    'id': '0luDJsRYWbHW2Sj1I5TPrE',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/2347e5b982d586ed2688f42a66c0ce5d17e1b283',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/3b37b7ca41a31b60407a34024f1e8d6da9d401d6',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ee194bac8bfe806922a27ddf90899c6aee5eff87',
#      'width': 160}],
#    'name': 'La Gossa Sorda',
#    'popularity': 48,
#    'type': 'artist',
#    'uri': 'spotify:artist:0luDJsRYWbHW2Sj1I5TPrE'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3msvxEo03ktYlej2y2j3lF'},
#    'followers': {'href': None, 'total': 33011},
#    'genres': ['cantautor', 'catalan folk', 'indie catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/3msvxEo03ktYlej2y2j3lF',
#    'id': '3msvxEo03ktYlej2y2j3lF',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ba59964a41d0e7f477d735fb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ba59964a41d0e7f477d735fb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ba59964a41d0e7f477d735fb',
#      'width': 64}],
#    'name': 'Sau',
#    'popularity': 42,
#    'type': 'artist',
#    'uri': 'spotify:artist:3msvxEo03ktYlej2y2j3lF'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ebwHQYvONnv8xIrW2wYDA'},
#    'followers': {'href': None, 'total': 7246},
#    'genres': ['cantautor', 'catalan folk', 'indie catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/3ebwHQYvONnv8xIrW2wYDA',
#    'id': '3ebwHQYvONnv8xIrW2wYDA',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738e02d8d54be7ccb1b0dc8b9f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028e02d8d54be7ccb1b0dc8b9f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518e02d8d54be7ccb1b0dc8b9f',
#      'width': 64}],
#    'name': "Whiskyn's",
#    'popularity': 28,
#    'type': 'artist',
#    'uri': 'spotify:artist:3ebwHQYvONnv8xIrW2wYDA'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5qPeAT4ikl6gJNUexAOEy0'},
#    'followers': {'href': None, 'total': 56294},
#    'genres': ['indie catala', 'reggae catala'],
#    'href': 'https://api.spotify.com/v1/artists/5qPeAT4ikl6gJNUexAOEy0',
#    'id': '5qPeAT4ikl6gJNUexAOEy0',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/d62aae2f4ac0fbb52c60a8322a07d6c828ce7883',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/a29a7850c39f4cb5e7f63a0d65926f9aba361421',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/a27220880f53065f5d76d6689be0370240b62c35',
#      'width': 160}],
#    'name': 'Oques Grasses',
#    'popularity': 57,
#    'type': 'artist',
#    'uri': 'spotify:artist:5qPeAT4ikl6gJNUexAOEy0'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1qNkvcsEC2Hry31JWkYO3D'},
#    'followers': {'href': None, 'total': 61715},
#    'genres': ['cantautor', 'indie catala', 'rock catala'],
#    'href': 'https://api.spotify.com/v1/artists/1qNkvcsEC2Hry31JWkYO3D',
#    'id': '1qNkvcsEC2Hry31JWkYO3D',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/611ff1a2db538f20154ee523c47decdf1e1e54c0',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/c4161a0a8bf0fc59845bb291f09c58cb31f73dcc',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/43685fbaf935aa42e592c382aa5184de207ebdf9',
#      'width': 160}],
#    'name': 'Sopa De Cabra',
#    'popularity': 48,
#    'type': 'artist',
#    'uri': 'spotify:artist:1qNkvcsEC2Hry31JWkYO3D'}]}

# %% [markdown]
# # 1. Dataset of Global Artists (Main Artists)
#
# Dataset downloaded from the html page: https://kworb.net/spotify/artists.html

# %%
def get_html(url):
    """
    Searches a url and retrieves an html and returns the object soup from bs4
    """
    # Requests the html of this page
    r = requests.get(url)
    r.encoding = 'utf-8'
    
    # Read the html text with Beautiful soup
    soup = BeautifulSoup(r.text, 'html.parser')
    
    return soup

# %%
def get_dataset():
    """
    Download the dataset from https://kworb.net/spotify/artists.html of global artists in Spotify
    """
    
    # Get the rows
    soup = get_html("https://kworb.net/spotify/artists.html")
    
    # Find the table where there are the artists sorted by streams
    table = soup.find('table')
    
    # Get the rows
    table_rows = table.find_all("tr")
    
    # For each row, append to a list the three columns of that table in a sublist
    l = []
    for tr in tqdm.tqdm(table_rows):
        td = tr.find_all('td')
        row = [tr.text for tr in td]
        if len(row)==3:
            l.append(row)
    
    # Convert the list of list into a dataframe
    df_art = pd.DataFrame(l, columns=["position", "artist", "streams"])
    return df_art

# %%
df = get_dataset()
# Out:
# 100%|██████████| 10001/10001 [00:00<00:00, 69219.63it/s]

# %%
df.head(5)
# Out:
#   position         artist         streams
# 0        1          Drake  19,730,111,322
# 1        2    Post Malone  14,381,513,844
# 2        3     Ed Sheeran  14,038,325,763
# 3        4       J Balvin  13,123,142,801
# 4        5  Justin Bieber  11,891,559,063

# %%
# Final list of artists
final_list_artists = df.artist.str.lower().tolist()

# %%
# Otras: otras canciones que no aparecen en la pagina kworb:
other_list_artists = []

# %% [markdown]
# # 2. Top Artists in Spain (Main Artists)
#
# Artists that have a famous song among the top 3000 songs of Spain

# %%
def get_dataset_spain():
    """
    Download the dataset from https://kworb.net/spotify/artists.html of global artists in Spotify
    """
    
    soup = get_html("https://kworb.net/spotify/country/es_weekly_totals.html")

    # Find the table where there are the artists sorted by streams
    table_d1 = soup.find_all('tr', {"class": "d1"})
    table_d0 = soup.find_all('tr', {"class": "d0"})

    # Append all the results into a single table
    table = []
    for ss in table_d1:
        table.append(ss)
    for ss in table_d0:
        table.append(ss)

    # The first <a href=...> that appears is the name of the artist
    l = []
    for tr in tqdm.tqdm(table):
        txt = tr.find("a").text
        l.append(txt)

    df_art = pd.DataFrame(l, columns=["artist"])
    return df_art

# %%
df_spain = get_dataset_spain()
# Out:
# 100%|██████████| 3615/3615 [00:00<00:00, 46775.47it/s]

# %% [markdown]
# We will make the intersection of artists from the Global charts and the Top Spanish charts in order to avoid replicating the same artist twice. We will add those artists that are in Spanish list but are not in Global to the list of artists.

# %%
# Avoid adding repeated artists
set_global = set(df.artist.str.lower())
set_spain = set(df_spain.artist.str.lower())
inters = set_global & set_spain
except_art = list(set_spain - set_global)

# %%
len(except_art)
# Out:
# 120

# %%
# Final list of artists
for art in except_art:
    final_list_artists.append(art)

# %% [markdown]
# # 3. Also known Spanish artists (Other artists)

# %% [markdown]
# Songs that we not in the kworb.net, will be investigated with the Spotify API. So we will store them separately:

# %%
# Otras Españolas
lista_otras_esp = ["Mägo de Oz", "La Casa Azul", "Amaral", "M-Clan"]
lista_otras_esp = [xx.lower() for xx in lista_otras_esp]

# Final list of artists
for art in lista_otras_esp:
    other_list_artists.append(art)

# %% [markdown]
# ## 3.1 Top Artists in Catalonia (Other Artists)

# %% [markdown]
# These artists do not appear in the kworb.net so we will get them via Spotify API:

# %%
lista_cat = [
    "Txarango",
    "Oques Grasses",
    "La Pegatina",
    "Buhos",
    "Doctor Prats",
    "Els Catarres",
    "Els Amics De Les Arts",
    "Gertrudis",
    "Gossos",
    "Sopa de Cabra",
    "Lax'n'Busto",
    "Vuit",
    "Suu",
    "Teràpia de Shock",
    "Els Pets",
    "Manel",
    "Blaumut",
    "Lluis Llach",
    "Sau",
    "Obrint Pas",
    "Clara Olóndriz",
    "Stay Homas",
    "Joan Dausà",
    "Joan Manuel Serrat",
    "Cesk Freixas",
    "Roba Estesa"
    
]

lista_cat = [xx.lower() for xx in lista_cat]

# %%
# Final list of artists
for art in lista_cat:
    other_list_artists.append(art)

# %% [markdown]
# # 4. Spotify API
#
# We will search for the artist_id and the tracks of the *other_list_artists* which were artists popular but not found in the dataset that we will exploit:

# %%
other_list_artists
# Out:
# ['mägo de oz',
#  'la casa azul',
#  'amaral',
#  'm-clan',
#  'txarango',
#  'oques grasses',
#  'la pegatina',
#  'buhos',
#  'doctor prats',
#  'els catarres',
#  'els amics de les arts',
#  'gertrudis',
#  'gossos',
#  'sopa de cabra',
#  "lax'n'busto",
#  'vuit',
#  'suu',
#  'teràpia de shock',
#  'els pets',
#  'manel',
#  'blaumut',
#  'lluis llach',
#  'sau',
#  'obrint pas',
#  'clara olóndriz',
#  'stay homas',
#  'joan dausà',
#  'joan manuel serrat',
#  'cesk freixas',
#  'roba estesa']

# %%
len(other_list_artists)
# Out:
# 8
